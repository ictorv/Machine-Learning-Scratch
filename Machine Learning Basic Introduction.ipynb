# %% [markdown]
# # What is Machine Learning

# %% [markdown]
# ![difference-traditional-software-machine-learning.jpg](attachment:46e9787b-242a-40b1-8374-f7e64e3adebd.jpg)

# %% [markdown]
# # Use case Machine Learning

# %% [markdown]
# 1. Email Spam Classifier will find Pattern - Long list of if else using traditional programming
# 2. Image Classification Different Breed
# 3. Data Mining - find pattern in machine learning data

# %% [markdown]
# # History of Machine Learning

# %% [markdown]
# 1. Data Gatethering - tedious task
# 2. High Hardware Demand (12 GB RAM in my phone 😁)

# %% [markdown]
# # Salary

# %% [markdown]
# ![Screenshot-29.png](attachment:9ae7e8f0-f549-470a-8879-ec95881b8032.png)

# %% [markdown]
# # AI vs ML vs DL

# %% [markdown]
# ![1702597301870.png](attachment:237531d6-7b26-494f-a362-5e74ef50b4d6.png)

# %% [markdown]
# + AI - intelligence in machine
# Intelligence ?
#     - Pattern Recogntion (Mostly we do in AI)
#     - Creativity and Imagination
#     - Emotional Intelligence (What is Emotion of Anger, Love 😒)

# %% [markdown]
# ### AI History
# + Symbolic AI
# + Expert System 80s (Work only specific purpose)
# + Machine Learning: Pattern in Data, No explicit programming

# %% [markdown]
# ### Deep Learning

# %% [markdown]
# + Is machine Learning
# + Algorithms is differnet
# + Inspired by Biological neuron

# %% [markdown]
# Dog and Cat classsification
# + ML need features like fur, face etc.
# + DL create features of its own

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Types of Machine Learning

# %% [markdown]
# ![machine-learning-types-infographics_1.png](attachment:48861ba0-470a-45b5-9aff-61a327651ee9.png)
